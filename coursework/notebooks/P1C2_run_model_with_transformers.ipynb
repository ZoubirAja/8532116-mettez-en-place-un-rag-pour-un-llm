# %% [markdown]
# # Utilisation du Modèle Chocolatine-3B pour la Génération de Texte
# ---
#
# Ce notebook démontre comment charger et utiliser le modèle jpacifico/Chocolatine-3B-Instruct-DPO-v1.2 de Hugging Face pour répondre à une question simple en français.
#
# Étapes :
#
# - Chargement des dépendances : Importation des classes AutoModelForCausalLM et AutoTokenizer de la bibliothèque transformers  https://huggingface.co/docs/transformers/fr/index
# - Chargement du Modèle et du Tokenizer : On spécifie le nom du modèle pré-entraîné (jpacifico/Chocolatine-3B-Instruct-DPO-v1.2) et on charge le modèle lui-même ainsi que son tokenizer associé. Le tokenizer est essentiel pour convertir le texte en un format compréhensible par le modèle.
# - Préparation de l'entrée : On définit la question à poser au modèle. Cette question est ensuite passée au tokenizer, qui la convertit en input_ids (des identifiants numériques pour chaque token/mot) et crée un attention_mask.
# - Génération de la réponse : On utilise la méthode generate() du modèle pour produire du texte.
# inputs["input_ids"]: Les tokens de la question.
# attention_mask: Indique au modèle quels tokens sont importants (pas du padding).
# max_new_tokens=50: Limite la longueur de la nouvelle partie générée (la réponse) à 50 tokens.
# num_return_sequences=1: On demande une seule réponse possible.
# - Décodage et Affichage : La sortie brute du modèle (une séquence d'IDs) est décodée par le tokenizer pour la reconvertir en texte lisible. On affiche ensuite la question originale et la réponse générée.

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

# 1. Charger le modèle et le tokenizer
model_name = "jpacifico/Chocolatine-3B-Instruct-DPO-v1.2"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name)

# 2. Préparer la question pour le modèle
question = "Quel est le département numéro 29 de la France ?"
inputs = tokenizer(question, return_tensors="pt", padding=True, truncation=True)

# 3. Générer une réponse avec le modèle
output = model.generate(
    inputs["input_ids"],
    attention_mask=inputs["attention_mask"],
    max_new_tokens=50,  # Remplace max_length
    num_return_sequences=1
)
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
# 4. Décoder et afficher la réponse
response = tokenizer.decode(output[0], skip_special_tokens=True)
print("Question :", question)
print("Réponse :", response)
# Out:
# Question : Quel est le département numéro 29 de la France ?
# Réponse : Quel est le département numéro 29 de la France ?
#
# Le département français numéro 29 est le Finistère. Il fait partie des départements métropolitains de la France, situé dans la région Bretagne. Le Finistère se trouve à l'ouest du pays,
